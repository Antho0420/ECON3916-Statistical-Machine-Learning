# %% [markdown]
# <a href="https://colab.research.google.com/github/tsarangler/ECON3916-Statistical-Machine-Learning/blob/main/Lab%203/Class_3_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rgdp = [1,2,3,4,5,6]

# %%
rgdp
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nations = ["A", "B", "C", "D", "E", "F"]

# %%
nations
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
dict = {
    "nations": nations,
    "rgdp": rgdp,
    "inflation": [3,2,1,1,2,3],
    "unemp": [1,2,1,2,2,3],
    "index": ["C6", "C2", "C1", "C4", "C5", "C3"]
}

# %%
dict
# Out:
# {'nations': ['A', 'B', 'C', 'D', 'E', 'F'],
#  'rgdp': [1, 2, 3, 4, 5, 6],
#  'inflation': [3, 2, 1, 1, 2, 3],
#  'unemp': [1, 2, 1, 2, 2, 3],
#  'index': ['C6', 'C2', 'C1', 'C4', 'C5', 'C3']}

# %%
import pandas as pd

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#   nations  rgdp  inflation  unemp index
# 0       A     1          3      1    C6
# 1       B     2          2      2    C2
# 2       C     3          1      1    C1
# 3       D     4          1      2    C4
# 4       E     5          2      2    C5
# 5       F     6          3      3    C3

# %%
#df["misery_index"] = df["inflation"] + df["unemp"]

# %%
df
# Out:
#   nations  rgdp  inflation  unemp index
# 0       A     1          3      1    C6
# 1       B     2          2      2    C2
# 2       C     3          1      1    C1
# 3       D     4          1      2    C4
# 4       E     5          2      2    C5
# 5       F     6          3      3    C3

# %%
rgdp = [1,2,3,4,5,6]

# %%
for i in rgdp:
  if i == 3:
    print(i)
# Out:
# 3

# %%
len(df)
# Out:
# 6

# %%
range(len(df))
# Out:
# range(0, 6)

# %%
for i in range(len(df)):
  if df.loc[i, "rgdp"] > 3:
    print(df.loc[i, "nations"])
# Out:
# D
# E
# F

# %%
df
# Out:
#   nations  rgdp  inflation  unemp index
# 0       A     1          3      1    C6
# 1       B     2          2      2    C2
# 2       C     3          1      1    C1
# 3       D     4          1      2    C4
# 4       E     5          2      2    C5
# 5       F     6          3      3    C3

# %%
df.set_index("index", inplace=True)

# %%
df
# Out:
#       nations  rgdp  inflation  unemp
# index
# C6          A     1          3      1
# C2          B     2          2      2
# C1          C     3          1      1
# C4          D     4          1      2
# C5          E     5          2      2
# C3          F     6          3      3

# %%
df.index = df.index.str.replace("C", "")

# %%
df
# Out:
#       nations  rgdp  inflation  unemp
# index
# 6           A     1          3      1
# 2           B     2          2      2
# 1           C     3          1      1
# 4           D     4          1      2
# 5           E     5          2      2
# 3           F     6          3      3

# %%
df = df.sort_index()

# %%
df
# Out:
#       nations  rgdp  inflation  unemp
# index
# 1           C     3          1      1
# 2           B     2          2      2
# 3           F     6          3      3
# 4           D     4          1      2
# 5           E     5          2      2
# 6           A     1          3      1

# %%
df = df.T

# %%
df
# Out:
# index      1  2  3  4  5  6
# nations    C  B  F  D  E  A
# rgdp       3  2  6  4  5  1
# inflation  1  2  3  1  2  3
# unemp      1  2  3  2  2  1

# %%
df = df.T

# %%
df
# Out:
#       nations rgdp inflation unemp
# index
# 1           C    3         1     1
# 2           B    2         2     2
# 3           F    6         3     3
# 4           D    4         1     2
# 5           E    5         2     2
# 6           A    1         3     1

# %%
def my_function():
  print("Hello Huskies!")

# %%
my_function()
# Out:
# Hello Huskies!

# %%
def misery_index_fun(unemp,inflation):
  z = unemp + inflation
  return z

# %%
misery_index_fun(df["inflation"], df["unemp"])
# Out:
# index
# 1    2
# 2    4
# 3    6
# 4    3
# 5    4
# 6    4
# dtype: object

# %%
def gdp_filter(i):
  """This will filter out the nations name for certain benchmark x"""
  for i in range(len(df)):
    if df.loc[i, "rgdp"] > 3:
      print(df.loc[i, "nations"])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["unemp"],df["inflation"], "ro")
plt.title("RGDP")
plt.xlabel("Nations")
plt.ylabel("RGDP")
plt.show()
